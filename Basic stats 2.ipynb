# %%
import pandas as pd
import numpy as np

# %% [raw]
# Problem Statement : Hospital Patient Data Analysis
# Context:
# A hospital maintains patient records including admission details, department, diagnosis, doctor, and bill amount. You have two datasets: one with patient info and another with billing details. Some patients have blank bill amounts, and there are multiple rows for the same patient due to follow-ups.
# Tasks:
# 1.	Load the patient dataset and show summary with info().
# 2.	Select only the columns relevant for billing: ['PatientID', 'Department', 'Doctor', 'BillAmount'].
# 3.	Drop administrative columns like ['ReceptionistID', 'CheckInTime'].
# 4.	Use groupby to find total bill amount per department.
# 5.	Remove duplicate patient records based on PatientID.
# 6.	Fill missing BillAmount values with the mean bill amount.
# 7.	Merge the billing dataset with patient dataset on PatientID.
# 8.	Concatenate an additional DataFrame that contains new patients for the current week (row-wise).
# 9.	Concatenate new billing category columns like ['InsuranceCovered', 'FinalAmount'] (column-wise).

# %% [raw]
# data1 = patient data
# data2 = billing data

# %%
data1 = pd.read_csv("Patient_Data.csv")

# %%
data2 = pd.read_csv("Billing_Data.csv")

# %% [markdown]
# ### EDA of data1

# %%
data1.shape
# Out:
# (6, 7)

# %%
data1.size
# Out:
# 42

# %%
data1.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
data1[['PatientID','Department','Doctor','BillAmount']]
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
data1.drop(columns = ['ReceptionistID','CheckInTime'],inplace = True)

# %%
data1.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
data1.duplicated().sum()
# Out:
# np.int64(1)

# %%
data1.drop_duplicates(inplace = True)

# %%
data1.isnull().sum()
# Out:
# PatientID     0
# Name          0
# Department    0
# Doctor        0
# BillAmount    2
# dtype: int64

# %%
data1.fillna(data1.BillAmount.mean(),inplace = True)

# %%
data1.isnull().sum()
# Out:
# PatientID     0
# Name          0
# Department    0
# Doctor        0
# BillAmount    0
# dtype: int64

# %%
data1.groupby('Department')['BillAmount'].sum()
# Out:
# Department
# Cardiology     11200.000000
# Dermatology     6233.333333
# Neurology       6233.333333
# Orthopedics     7500.000000
# Name: BillAmount, dtype: float64

# %% [markdown]
# ### EDA of data2

# %%
data2.head()
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
data2.duplicated().sum()
# Out:
# np.int64(0)

# %%
data2.isnull().sum()
# Out:
# PatientID           0
# InsuranceCovered    0
# FinalAmount         0
# dtype: int64

# %% [raw]
# 7.	Merge the billing dataset with patient dataset on PatientID.

# %%
new_data = pd.merge(data1,data2,on = 'PatientID')

# %%
new_data.head()
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000              2000
# 1        102      Bob    Neurology   Dr. John  6233.333333              1500
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000              2500
# 3        104    David   Cardiology  Dr. Smith  6200.000000              3000
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %% [raw]
# 8. 8.	Concatenate an additional DataFrame that contains new patients for the current week (row-wise).

# %%
week_data = {
    'PatientID': [6, 7],
    'Name': ['Rahul', 'Amit']
}

# %%
df = pd.DataFrame(week_data)

# %%
new_df = pd.concat([data1, data2], axis=1).reset_index(drop=True)

# %%
new_df
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  PatientID  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000        101
# 1        102      Bob    Neurology   Dr. John  6233.333333        102
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000        103
# 3        104    David   Cardiology  Dr. Smith  6200.000000        104
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333        105
#
#    InsuranceCovered  FinalAmount
# 0              2000         3000
# 1              1500         3500
# 2              2500         5000
# 3              3000         3200
# 4              1000         4000

# %% [raw]
# 9.	Concatenate new billing category columns like ['InsuranceCovered', 'FinalAmount'] (column-wise).

# %%
week_data = {
    'InsuranceCovered': [6, 7],
    'FinalAmount': [9000, 4000]
}

# %%
df = pd.DataFrame(week_data)

# %%
new_df = pd.concat([data1, data2], axis=1).reset_index(drop=True)

# %%
new_df
# Out:
#    PatientID     Name   Department     Doctor   BillAmount  PatientID  \
# 0        101    Alice   Cardiology  Dr. Smith  5000.000000        101
# 1        102      Bob    Neurology   Dr. John  6233.333333        102
# 2        103  Charlie  Orthopedics    Dr. Lee  7500.000000        103
# 3        104    David   Cardiology  Dr. Smith  6200.000000        104
# 4        105      Eva  Dermatology   Dr. Rose  6233.333333        105
#
#    InsuranceCovered  FinalAmount
# 0              2000         3000
# 1              1500         3500
# 2              2500         5000
# 3              3000         3200
# 4              1000         4000
